# %% [markdown]
# # PyCaret AutoML Analysis for Battery Capacity Prediction
#
# This notebook uses PyCaret's regression module to automatically test and compare multiple machine learning models on the battery capacity dataset.
#
# ## ⚠️ Important: SciPy Compatibility Fix
#
# If you get an error like: `ImportError: cannot import name 'interp' from 'scipy'`
#
# **Quick Fix:** Run this in a terminal:
# ```bash
# pip install scipy==1.11.4
# pip install pycaret==3.3.2
# ```
#
# Or run the automated fix script:
# ```bash
# python fix_pycaret_install.py
# ```
#
# ## Models that will be tested:
# - **Linear Models**: Linear Regression, Lasso, Ridge, Elastic Net, Huber, Bayesian Ridge
# - **Tree-based**: Random Forest, Extra Trees, Decision Tree, Gradient Boosting, AdaBoost
# - **Advanced Boosting**: LightGBM, XGBoost, CatBoost
# - **Other**: SVM, K-Nearest Neighbors, Multi-Layer Perceptron (Neural Network)

# %%
# Fix SciPy compatibility issue if needed
import subprocess
import sys

def fix_scipy_compatibility():
    """Fix the scipy compatibility issue with PyCaret"""
    try:
        # Try importing PyCaret first
        from pycaret.regression import setup
        print("✅ PyCaret is working correctly!")
        return True
    except ImportError as e:
        if "interp" in str(e).lower():
            print("🔧 Fixing SciPy compatibility issue...")
            print("Installing compatible SciPy version...")
            subprocess.run([sys.executable, "-m", "pip", "install", "scipy==1.11.4"], check=True)
            subprocess.run([sys.executable, "-m", "pip", "install", "pycaret==3.3.2"], check=True)
            print("✅ Fix applied! Please restart the kernel and try again.")
            return False
        else:
            print(f"❌ Different import error: {e}")
            return False

# Run the compatibility check
if not fix_scipy_compatibility():
    print("🔄 Please restart the kernel and run this cell again.")
# Out:
# ✅ PyCaret is working correctly!

# %%
# Import required packages
import os
import pandas as pd
import numpy as np
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# PyCaret imports (should work now after fixing scipy)
from pycaret.regression import *

# Custom modules
from src.data_loader import DataLoader

print("✅ All imports successful!")
# Out:
# ✅ All imports successful!

# %% [markdown]
# # PyCaret AutoML Analysis for Battery Capacity Prediction
#
# This notebook uses PyCaret's regression module to automatically test and compare multiple machine learning models on the battery capacity dataset.
#
# ## Models that will be tested:
# - **Linear Models**: Linear Regression, Lasso, Ridge, Elastic Net, Huber, Bayesian Ridge
# - **Tree-based**: Random Forest, Extra Trees, Decision Tree, Gradient Boosting, AdaBoost
# - **Advanced Boosting**: LightGBM, XGBoost, CatBoost
# - **Other**: SVM, K-Nearest Neighbors, Multi-Layer Perceptron (Neural Network)

# %%
# Install PyCaret if not already installed
# !pip install pycaret==3.3.2
# Out:
# Collecting pycaret==3.3.2
#   Obtaining dependency information for pycaret==3.3.2 from https://files.pythonhosted.org/packages/3e/6f/b3d59fac3869a7685e68aecdd35c336800bce8c8d3b45687bb82cf9a2848/pycaret-3.3.2-py3-none-any.whl.metadata
#   Downloading pycaret-3.3.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: ipython>=5.5.0 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from pycaret==3.3.2) (8.18.1)
# Collecting ipywidgets>=7.6.5 (from pycaret==3.3.2)
#   Obtaining dependency information for ipywidgets>=7.6.5 from https://files.pythonhosted.org/packages/58/6a/9166369a2f092bd286d24e6307de555d63616e8ddb373ebad2b5635ca4cd/ipywidgets-8.1.7-py3-none-any.whl.metadata
#   Downloading ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Collecting tqdm>=4.62.0 (from pycaret==3.3.2)
#   Obtaining dependency information for tqdm>=4.62.0 from https://files.pythonhosted.org/packages/d0/30/dc54f88dd4a2b5dc8a0279bdd7270e735851848b762aeb1c1184ed1f6b14/tqdm-4.67.1-py3-none-any.whl.metadata
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: numpy<1.27,>=1.21 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from pycaret==3.3.2) (1.24.3)
# Requirement already satisfied: pandas<2.2.0 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from pycaret==3.3.2) (2.0.3)
# Requirement already satisfied: jinja2>=3 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from pycaret==3.3.2) (3.1.6)
# Collecting scipy<=1.11.4,>=1.6.1 (from pycaret==3.3.2)
#   Obtaining dependency information for scipy<=1.11.4,>=1.6.1 from https://files.pythonhosted.org/packages/d1/3a/0ab839bb67043ab35e5dcf8b611ca9e08e5a8933b0bc7506eedcec664aae/scipy-1.11.4-cp39-cp39-macosx_12_0_arm64.whl.metadata
#   Downloading scipy-1.11.4-cp39-cp39-macosx_12_0_arm64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: joblib<1.4,>=1.2.0 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from pycaret==3.3.2) (1.3.1)
# Collecting scikit-learn>1.4.0 (from pycaret==3.3.2)
#   Obtaining dependency information for scikit-learn>1.4.0 from https://files.pythonhosted.org/packages/83/74/f64379a4ed5879d9db744fe37cfe1978c07c66684d2439c3060d19a536d8/scikit_learn-1.6.1-cp39-cp39-macosx_12_0_arm64.whl.metadata
#   Downloading scikit_learn-1.6.1-cp39-cp39-macosx_12_0_arm64.whl.metadata (31 kB)
# Collecting pyod>=1.1.3 (from pycaret==3.3.2)
#   Obtaining dependency information for pyod>=1.1.3 from https://files.pythonhosted.org/packages/29/38/dee2fc597010654c3a7588f0990192680c5f2d405fbf6f2e5f5c4df1c736/pyod-2.0.5-py3-none-any.whl.metadata
#   Downloading pyod-2.0.5-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 1.3 MB/s eta 0:00:00
# Collecting imbalanced-learn>=0.12.0 (from pycaret==3.3.2)
#   Obtaining dependency information for imbalanced-learn>=0.12.0 from https://files.pythonhosted.org/packages/d8/0d/c3bfccc5d460eec8ff56889802aa88f5d07280d5282b307a74558e6edc44/imbalanced_learn-0.12.4-py3-none-any.whl.metadata
#   Downloading imbalanced_learn-0.12.4-py3-none-any.whl.metadata (8.3 kB)
# Collecting category-encoders>=2.4.0 (from pycaret==3.3.2)
#   Obtaining dependency information for category-encoders>=2.4.0 from https://files.pythonhosted.org/packages/98/47/598b4bf0ccf6f02915e71bdd23fe846a27adc2d3ba734f2ba5215d8e44f5/category_encoders-2.6.4-py2.py3-none-any.whl.metadata
#   Downloading category_encoders-2.6.4-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting lightgbm>=3.0.0 (from pycaret==3.3.2)
#   Obtaining dependency information for lightgbm>=3.0.0 from https://files.pythonhosted.org/packages/21/1b/550ee378512b78847930f5d74228ca1fdba2a7fbdeaac9aeccc085b0e257/lightgbm-4.6.0-py3-none-macosx_12_0_arm64.whl.metadata
#   Downloading lightgbm-4.6.0-py3-none-macosx_12_0_arm64.whl.metadata (17 kB)
# Collecting numba>=0.55.0 (from pycaret==3.3.2)
#   Obtaining dependency information for numba>=0.55.0 from https://files.pythonhosted.org/packages/28/14/a5baa1f2edea7b49afa4dc1bb1b126645198cf1075186853b5b497be826e/numba-0.60.0-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading numba-0.60.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Requirement already satisfied: requests>=2.27.1 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from pycaret==3.3.2) (2.32.4)
# Requirement already satisfied: psutil>=5.9.0 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from pycaret==3.3.2) (7.0.0)
# Requirement already satisfied: markupsafe>=2.0.1 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from pycaret==3.3.2) (3.0.2)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from pycaret==3.3.2) (8.7.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from pycaret==3.3.2) (5.10.4)
# Collecting cloudpickle (from pycaret==3.3.2)
#   Obtaining dependency information for cloudpickle from https://files.pythonhosted.org/packages/7e/e8/64c37fadfc2816a7701fa8a6ed8d87327c7d54eacfbfb6edab14a2f2be75/cloudpickle-3.1.1-py3-none-any.whl.metadata
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting deprecation>=2.1.0 (from pycaret==3.3.2)
#   Obtaining dependency information for deprecation>=2.1.0 from https://files.pythonhosted.org/packages/02/c3/253a89ee03fc9b9682f1541728eb66db7db22148cd94f89ab22528cd1e1b/deprecation-2.1.0-py2.py3-none-any.whl.metadata
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting xxhash (from pycaret==3.3.2)
#   Obtaining dependency information for xxhash from https://files.pythonhosted.org/packages/7c/a8/b2a42b6c9ae46e233f474f3d307c2e7bca8d9817650babeca048d2ad01d6/xxhash-3.5.0-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading xxhash-3.5.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib<3.8.0 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from pycaret==3.3.2) (3.7.2)
# Collecting scikit-plot>=0.3.7 (from pycaret==3.3.2)
#   Obtaining dependency information for scikit-plot>=0.3.7 from https://files.pythonhosted.org/packages/7c/47/32520e259340c140a4ad27c1b97050dd3254fdc517b1d59974d47037510e/scikit_plot-0.3.7-py3-none-any.whl.metadata
#   Downloading scikit_plot-0.3.7-py3-none-any.whl.metadata (7.1 kB)
# Collecting yellowbrick>=1.4 (from pycaret==3.3.2)
#   Obtaining dependency information for yellowbrick>=1.4 from https://files.pythonhosted.org/packages/06/35/c7d44bb541c06bc41b3239b27af79ea0ecc7dbb156ee1335576f99c58b91/yellowbrick-1.5-py3-none-any.whl.metadata
#   Downloading yellowbrick-1.5-py3-none-any.whl.metadata (7.7 kB)
# Collecting plotly>=5.14.0 (from pycaret==3.3.2)
#   Obtaining dependency information for plotly>=5.14.0 from https://files.pythonhosted.org/packages/95/a9/12e2dc726ba1ba775a2c6922d5d5b4488ad60bdab0888c337c194c8e6de8/plotly-6.3.0-py3-none-any.whl.metadata
#   Downloading plotly-6.3.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting kaleido>=0.2.1 (from pycaret==3.3.2)
#   Obtaining dependency information for kaleido>=0.2.1 from https://files.pythonhosted.org/packages/28/0e/853df00cac4823eaa8f35114d0d0ad1e2ec6b8243ce4acf5f8ac5235c517/kaleido-1.0.0-py3-none-any.whl.metadata
#   Downloading kaleido-1.0.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting schemdraw==0.15 (from pycaret==3.3.2)
#   Obtaining dependency information for schemdraw==0.15 from https://files.pythonhosted.org/packages/8f/28/8b59385b5b4d89ba9a5710bd5d014e8fdc7823d66e15cb6f867bb0c59adc/schemdraw-0.15-py3-none-any.whl.metadata
#   Downloading schemdraw-0.15-py3-none-any.whl.metadata (2.2 kB)
# Collecting plotly-resampler>=0.8.3.1 (from pycaret==3.3.2)
#   Obtaining dependency information for plotly-resampler>=0.8.3.1 from https://files.pythonhosted.org/packages/77/df/921eff232a2a8da7bdf84688b8cacfd9cef1bdc8fe695c547f7994804bee/plotly_resampler-0.11.0-py3-none-any.whl.metadata
#   Downloading plotly_resampler-0.11.0-py3-none-any.whl.metadata (13 kB)
# Collecting statsmodels>=0.12.1 (from pycaret==3.3.2)
#   Obtaining dependency information for statsmodels>=0.12.1 from https://files.pythonhosted.org/packages/44/ec/091dc1e69bbc84139e3409e45ac26e285ef41eb67116d13e094cdde7804d/statsmodels-0.14.5-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading statsmodels-0.14.5-cp39-cp39-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting sktime==0.26.0 (from pycaret==3.3.2)
#   Obtaining dependency information for sktime==0.26.0 from https://files.pythonhosted.org/packages/90/4c/ef5aa0d46210e974df138cc014955d2d5acb6d36af0ce1ee145d276e4a35/sktime-0.26.0-py3-none-any.whl.metadata
#   Downloading sktime-0.26.0-py3-none-any.whl.metadata (29 kB)
# Collecting tbats>=1.1.3 (from pycaret==3.3.2)
#   Obtaining dependency information for tbats>=1.1.3 from https://files.pythonhosted.org/packages/63/94/1949dc644c3fa05b736b988dc8058122f8c0187778ff9f18070bce2d4ddd/tbats-1.1.3-py3-none-any.whl.metadata
#   Downloading tbats-1.1.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting pmdarima>=2.0.4 (from pycaret==3.3.2)
#   Obtaining dependency information for pmdarima>=2.0.4 from https://files.pythonhosted.org/packages/7f/0f/4b0b7f6f363d8a6d92230be78d5a14a97834e29d24c9a264d24bb95a092d/pmdarima-2.0.4-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading pmdarima-2.0.4-cp39-cp39-macosx_11_0_arm64.whl.metadata (7.8 kB)
# Collecting wurlitzer (from pycaret==3.3.2)
#   Obtaining dependency information for wurlitzer from https://files.pythonhosted.org/packages/9a/24/93ce54550a9dd3fd996ed477f00221f215bf6da3580397fbc138d6036e2e/wurlitzer-3.1.1-py3-none-any.whl.metadata
#   Downloading wurlitzer-3.1.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: packaging in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from sktime==0.26.0->pycaret==3.3.2) (25.0)
# Collecting scikit-base<0.8.0 (from sktime==0.26.0->pycaret==3.3.2)
#   Obtaining dependency information for scikit-base<0.8.0 from https://files.pythonhosted.org/packages/4b/52/d74060accfcb4b3110d93e684416f2632e3dbff18e2429938a7134f1d800/scikit_base-0.7.8-py3-none-any.whl.metadata
#   Downloading scikit_base-0.7.8-py3-none-any.whl.metadata (8.8 kB)
# Collecting scikit-learn>1.4.0 (from pycaret==3.3.2)
#   Obtaining dependency information for scikit-learn>1.4.0 from https://files.pythonhosted.org/packages/d9/ff/5ae7e924925499902104bf046ccd9b2b2e078171bcedc4ee2e2f2d2cacca/scikit_learn-1.4.2-cp39-cp39-macosx_12_0_arm64.whl.metadata
#   Downloading scikit_learn-1.4.2-cp39-cp39-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting patsy>=0.5.1 (from category-encoders>=2.4.0->pycaret==3.3.2)
#   Obtaining dependency information for patsy>=0.5.1 from https://files.pythonhosted.org/packages/87/2b/b50d3d08ea0fc419c183a84210571eba005328efa62b6b98bc28e9ead32a/patsy-1.0.1-py2.py3-none-any.whl.metadata
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from imbalanced-learn>=0.12.0->pycaret==3.3.2) (3.6.0)
# Requirement already satisfied: zipp>=3.20 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from importlib-metadata>=4.12.0->pycaret==3.3.2) (3.23.0)
# Requirement already satisfied: decorator in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret==3.3.2) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret==3.3.2) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret==3.3.2) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret==3.3.2) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret==3.3.2) (2.19.2)
# Requirement already satisfied: stack-data in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret==3.3.2) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret==3.3.2) (5.14.3)
# Requirement already satisfied: typing-extensions in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret==3.3.2) (4.14.1)
# Requirement already satisfied: exceptiongroup in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret==3.3.2) (1.3.0)
# Requirement already satisfied: pexpect>4.3 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret==3.3.2) (4.9.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret==3.3.2) (0.2.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets>=7.6.5->pycaret==3.3.2)
#   Obtaining dependency information for widgetsnbextension~=4.0.14 from https://files.pythonhosted.org/packages/ca/51/5447876806d1088a0f8f71e16542bf350918128d0a69437df26047c8e46f/widgetsnbextension-4.0.14-py3-none-any.whl.metadata
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets>=7.6.5->pycaret==3.3.2)
#   Obtaining dependency information for jupyterlab_widgets~=3.0.15 from https://files.pythonhosted.org/packages/43/6a/ca128561b22b60bd5a0c4ea26649e68c8556b82bc70a0c396eebc977fe86/jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata
#   Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Collecting choreographer>=1.0.5 (from kaleido>=0.2.1->pycaret==3.3.2)
#   Obtaining dependency information for choreographer>=1.0.5 from https://files.pythonhosted.org/packages/d3/c2/82389f6e20098a414ddcf88d3b8032809b7a66e70f9bc5264f81beb24b4a/choreographer-1.0.10-py3-none-any.whl.metadata
#   Downloading choreographer-1.0.10-py3-none-any.whl.metadata (5.6 kB)
# Collecting logistro>=1.0.8 (from kaleido>=0.2.1->pycaret==3.3.2)
#   Obtaining dependency information for logistro>=1.0.8 from https://files.pythonhosted.org/packages/bc/df/e51691ab004d74fa25b751527d041ad1b4d84ee86cbcb8630ab0d7d5188e/logistro-1.1.0-py3-none-any.whl.metadata
#   Downloading logistro-1.1.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting orjson>=3.10.15 (from kaleido>=0.2.1->pycaret==3.3.2)
#   Obtaining dependency information for orjson>=3.10.15 from https://files.pythonhosted.org/packages/99/a6/18d88ccf8e5d8f711310eba9b4f6562f4aa9d594258efdc4dcf8c1550090/orjson-3.11.3-cp39-cp39-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata
#   Downloading orjson-3.11.3-cp39-cp39-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (11.3.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from matplotlib<3.8.0->pycaret==3.3.2) (6.5.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret==3.3.2) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret==3.3.2) (4.25.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret==3.3.2) (5.8.1)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba>=0.55.0->pycaret==3.3.2)
#   Obtaining dependency information for llvmlite<0.44,>=0.43.0dev0 from https://files.pythonhosted.org/packages/cc/61/58c70aa0808a8cba825a7d98cc65bef4801b99328fba80837bfcb5fc767f/llvmlite-0.43.0-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading llvmlite-0.43.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from pandas<2.2.0->pycaret==3.3.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from pandas<2.2.0->pycaret==3.3.2) (2025.2)
# Collecting narwhals>=1.15.1 (from plotly>=5.14.0->pycaret==3.3.2)
#   Obtaining dependency information for narwhals>=1.15.1 from https://files.pythonhosted.org/packages/8a/8c/ac6f6bd2d118ac49e1bc0285e401c1dc50cf878d48156bbc7969902703b0/narwhals-2.4.0-py3-none-any.whl.metadata
#   Downloading narwhals-2.4.0-py3-none-any.whl.metadata (11 kB)
# Collecting dash>=2.11.0 (from plotly-resampler>=0.8.3.1->pycaret==3.3.2)
#   Obtaining dependency information for dash>=2.11.0 from https://files.pythonhosted.org/packages/d3/36/e0010483ca49b9bf6f389631ccea07b3ff6b678d14d8c7a0a4357860c36a/dash-3.2.0-py3-none-any.whl.metadata
#   Downloading dash-3.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting tsdownsample>=0.1.3 (from plotly-resampler>=0.8.3.1->pycaret==3.3.2)
#   Obtaining dependency information for tsdownsample>=0.1.3 from https://files.pythonhosted.org/packages/ff/bf/15160d980eda30f8dad99069dac1ea69923ecf2dd4e0f246a2ddac0d9906/tsdownsample-0.1.4.1-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading tsdownsample-0.1.4.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (8.0 kB)
# Collecting Cython!=0.29.18,!=0.29.31,>=0.29 (from pmdarima>=2.0.4->pycaret==3.3.2)
#   Obtaining dependency information for Cython!=0.29.18,!=0.29.31,>=0.29 from https://files.pythonhosted.org/packages/c8/33/8f343630d4d2e7c87bfadc5be99736678f304ef0c3f7a85ca05138f3d6a6/cython-3.1.3-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading cython-3.1.3-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.7 kB)
# Requirement already satisfied: urllib3 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from pmdarima>=2.0.4->pycaret==3.3.2) (2.5.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from pmdarima>=2.0.4->pycaret==3.3.2) (68.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from requests>=2.27.1->pycaret==3.3.2) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from requests>=2.27.1->pycaret==3.3.2) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from requests>=2.27.1->pycaret==3.3.2) (2025.8.3)
# Collecting simplejson>=3.19.3 (from choreographer>=1.0.5->kaleido>=0.2.1->pycaret==3.3.2)
#   Obtaining dependency information for simplejson>=3.19.3 from https://files.pythonhosted.org/packages/3c/2f/d0ff0b772d4ef092876eb85c99bc591c446b0502715551dad7dfc7f7c2c0/simplejson-3.20.1-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading simplejson-3.20.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Collecting Flask<3.2,>=1.0.4 (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2)
#   Obtaining dependency information for Flask<3.2,>=1.0.4 from https://files.pythonhosted.org/packages/ec/f9/7f9263c5695f4bd0023734af91bedb2ff8209e8de6ead162f35d8dc762fd/flask-3.1.2-py3-none-any.whl.metadata
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.2 (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2)
#   Obtaining dependency information for Werkzeug<3.2 from https://files.pythonhosted.org/packages/52/24/ab44c871b0f07f491e5d2ad12c9bd7358e527510618cb1b803a88e986db1/werkzeug-3.1.3-py3-none-any.whl.metadata
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting retrying (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2)
#   Obtaining dependency information for retrying from https://files.pythonhosted.org/packages/67/f3/6cd296376653270ac1b423bb30bd70942d9916b6978c6f40472d6ac038e7/retrying-1.4.2-py3-none-any.whl.metadata
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2) (1.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret==3.3.2) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.3.2) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.3.2) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.3.2) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret==3.3.2) (0.27.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret==3.3.2) (4.3.8)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.5.0->pycaret==3.3.2) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret==3.3.2) (0.2.13)
# Requirement already satisfied: six>=1.5 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib<3.8.0->pycaret==3.3.2) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from stack-data->ipython>=5.5.0->pycaret==3.3.2) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from stack-data->ipython>=5.5.0->pycaret==3.3.2) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/amirbabamahmoudi/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages (from stack-data->ipython>=5.5.0->pycaret==3.3.2) (0.2.3)
# Collecting blinker>=1.9.0 (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2)
#   Obtaining dependency information for blinker>=1.9.0 from https://files.pythonhosted.org/packages/10/cb/f2ad4230dc2eb1a74edf38f1a38b9b52277f75bef262d8908e60d957e13c/blinker-1.9.0-py3-none-any.whl.metadata
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting click>=8.1.3 (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2)
#   Obtaining dependency information for click>=8.1.3 from https://files.pythonhosted.org/packages/7e/d4/7ebdbd03970677812aac39c869717059dbb71a4cfc033ca6e5221787892c/click-8.1.8-py3-none-any.whl.metadata
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret==3.3.2)
#   Obtaining dependency information for itsdangerous>=2.2.0 from https://files.pythonhosted.org/packages/04/96/92447566d16df59b2a776c0fb82dbc4d9e07cd95062562af01e408583fc4/itsdangerous-2.2.0-py3-none-any.whl.metadata
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Downloading pycaret-3.3.2-py3-none-any.whl (486 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Downloading schemdraw-0.15-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 2.0 MB/s eta 0:00:00 0:00:01
# Downloading sktime-0.26.0-py3-none-any.whl (21.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 8.4 MB/s eta 0:00:0000:0100:01
# Downloading category_encoders-2.6.4-py2.py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading imbalanced_learn-0.12.4-py3-none-any.whl (258 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.3/258.3 kB 2.8 MB/s eta 0:00:00a 0:00:01
# Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Downloading kaleido-1.0.0-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 2.7 MB/s eta 0:00:00
# Downloading lightgbm-4.6.0-py3-none-macosx_12_0_arm64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 5.7 MB/s eta 0:00:00a 0:00:01
# Downloading numba-0.60.0-cp39-cp39-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 6.1 MB/s eta 0:00:00a 0:00:01
# Downloading plotly-6.3.0-py3-none-any.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 6.4 MB/s eta 0:00:0000:0100:01
# Downloading plotly_resampler-0.11.0-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 2.4 MB/s eta 0:00:0000:01
# Downloading pmdarima-2.0.4-cp39-cp39-macosx_11_0_arm64.whl (630 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 630.4/630.4 kB 4.7 MB/s eta 0:00:00a 0:00:01
# Downloading pyod-2.0.5-py3-none-any.whl (200 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.6/200.6 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Downloading scikit_learn-1.4.2-cp39-cp39-macosx_12_0_arm64.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 8.1 MB/s eta 0:00:0000:0100:01
# Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Downloading scipy-1.11.4-cp39-cp39-macosx_12_0_arm64.whl (29.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 3.4 MB/s eta 0:00:0000:0100:01
# Downloading statsmodels-0.14.5-cp39-cp39-macosx_11_0_arm64.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 1.9 MB/s eta 0:00:0000:0100:01
# Downloading tbats-1.1.3-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.1 MB/s eta 0:00:00
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.6/282.6 kB 2.8 MB/s eta 0:00:00a 0:00:01
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading wurlitzer-3.1.1-py3-none-any.whl (8.6 kB)
# Downloading xxhash-3.5.0-cp39-cp39-macosx_11_0_arm64.whl (30 kB)
# Downloading choreographer-1.0.10-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 kB 1.3 MB/s eta 0:00:0000:01
# Downloading cython-3.1.3-cp39-cp39-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 1.8 MB/s eta 0:00:0000:0100:01
# Downloading dash-3.2.0-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 2.5 MB/s eta 0:00:0000:0100:01
# Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Downloading llvmlite-0.43.0-cp39-cp39-macosx_11_0_arm64.whl (28.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 2.1 MB/s eta 0:00:0000:0100:01
# Downloading logistro-1.1.0-py3-none-any.whl (7.9 kB)
# Downloading narwhals-2.4.0-py3-none-any.whl (406 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 406.2/406.2 kB 3.2 MB/s eta 0:00:00a 0:00:01
# Downloading orjson-3.11.3-cp39-cp39-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (238 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.2/238.2 kB 2.6 MB/s eta 0:00:00a 0:00:01
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.9/232.9 kB 3.0 MB/s eta 0:00:00a 0:00:01
# Downloading scikit_base-0.7.8-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.1/130.1 kB 1.9 MB/s eta 0:00:00 0:00:01
# Downloading tsdownsample-0.1.4.1-cp39-cp39-macosx_11_0_arm64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 2.2 MB/s eta 0:00:0000:0100:01
# Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 2.8 MB/s eta 0:00:00a 0:00:01
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 3.6 MB/s eta 0:00:0000:01
# Downloading simplejson-3.20.1-cp39-cp39-macosx_11_0_arm64.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 3.7 MB/s eta 0:00:00
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 4.4 MB/s eta 0:00:00a 0:00:01
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 2.9 MB/s eta 0:00:00
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Installing collected packages: xxhash, wurlitzer, widgetsnbextension, Werkzeug, tsdownsample, tqdm, simplejson, scipy, scikit-base, schemdraw, retrying, patsy, orjson, narwhals, logistro, llvmlite, jupyterlab_widgets, itsdangerous, deprecation, Cython, cloudpickle, click, blinker, scikit-learn, plotly, numba, lightgbm, Flask, choreographer, yellowbrick, statsmodels, sktime, scikit-plot, pyod, kaleido, ipywidgets, imbalanced-learn, dash, pmdarima, plotly-resampler, category-encoders, tbats, pycaret
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.0
#     Uninstalling scikit-learn-1.3.0:
#       Successfully uninstalled scikit-learn-1.3.0
# Successfully installed Cython-3.1.3 Flask-3.1.2 Werkzeug-3.1.3 blinker-1.9.0 category-encoders-2.6.4 choreographer-1.0.10 click-8.1.8 cloudpickle-3.1.1 dash-3.2.0 deprecation-2.1.0 imbalanced-learn-0.12.4 ipywidgets-8.1.7 itsdangerous-2.2.0 jupyterlab_widgets-3.0.15 kaleido-1.0.0 lightgbm-4.6.0 llvmlite-0.43.0 logistro-1.1.0 narwhals-2.4.0 numba-0.60.0 orjson-3.11.3 patsy-1.0.1 plotly-6.3.0 plotly-resampler-0.11.0 pmdarima-2.0.4 pycaret-3.3.2 pyod-2.0.5 retrying-1.4.2 schemdraw-0.15 scikit-base-0.7.8 scikit-learn-1.4.2 scikit-plot-0.3.7 scipy-1.11.4 simplejson-3.20.1 sktime-0.26.0 statsmodels-0.14.5 tbats-1.1.3 tqdm-4.67.1 tsdownsample-0.1.4.1 widgetsnbextension-4.0.14 wurlitzer-3.1.1 xxhash-3.5.0 yellowbrick-1.5
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import pandas as pd
import numpy as np
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# PyCaret imports
from pycaret.regression import *

# Custom modules
from src.data_loader import DataLoader

print("✅ All imports successful!")
# Out:
# ✅ All imports successful!

# %%
# Initialize paths and load data
current_dir = Path.cwd()
data_path = current_dir / "dataset_299.xlsx"
results_dir = current_dir / "results"
results_dir.mkdir(exist_ok=True)

print(f"📁 Data path: {data_path}")
print(f"📁 Results directory: {results_dir}")
print(f"✅ Data file exists: {data_path.exists()}")
# Out:
# 📁 Data path: /Users/amirbabamahmoudi/Documents/Battery-Capacity/dataset_299.xlsx
# 📁 Results directory: /Users/amirbabamahmoudi/Documents/Battery-Capacity/results
# ✅ Data file exists: True

# %%
# Load and prepare data
print("Loading data...")
data_loader = DataLoader(data_path)
df = data_loader.load_data()
X, y = data_loader.split_features_target(df)

# Create a combined dataset for PyCaret (it expects target column in the dataframe)
data = X.copy()
data['target'] = y

print(f"📊 Dataset shape: {data.shape}")
print(f"🎯 Target variable: 'target' (Average Capacity)")
print(f"🔢 Number of features: {X.shape[1]}")
print(f"📈 Target statistics:")
print(y.describe())
# Out:
# Loading data...
# Successfully loaded data with shape: (299, 63)
# Index(['Cell ID', 'Average Capacity'], dtype='object')
# 📊 Dataset shape: (299, 62)
# 🎯 Target variable: 'target' (Average Capacity)
# 🔢 Number of features: 61
# 📈 Target statistics:
# count     299.000000
# mean     7758.993925
# std       624.947969
# min      4106.476500
# 25%      7617.600125
# 50%      7879.671500
# 75%      8123.505250
# max      8579.065042
# Name: Average Capacity, dtype: float64

# %%
# Setup PyCaret environment
print("Setting up PyCaret environment...")

reg = setup(
    data=data,
    target='target',
    session_id=123,
    train_size=0.8,
    fold=5,  # 5-fold cross-validation
    verbose=False,
    use_gpu=False  # Set to True if you have GPU support
)

print("✅ PyCaret environment successfully set up!")
print(f"📊 Training set size: {int(0.8 * len(data))} samples")
print(f"📊 Test set size: {int(0.2 * len(data))} samples")
print("🔄 Cross-validation: 5-fold")
# Out:
# Setting up PyCaret environment...
# ✅ PyCaret environment successfully set up!
# 📊 Training set size: 239 samples
# 📊 Test set size: 59 samples
# 🔄 Cross-validation: 5-fold

# %%
print("🤖 Training and comparing multiple regression models...")
print("This may take a few minutes...")

# First, compare all models without n_select to get the DataFrame
model_comparison = compare_models(
    include=[
        'lr',      # Linear Regression
        'lasso',   # Lasso Regression
        'ridge',   # Ridge Regression
        'en',      # Elastic Net
        'huber',   # Huber Regressor
        'rf',      # Random Forest
        'et',      # Extra Trees
        'gbr',     # Gradient Boosting
        'lightgbm', # LightGBM
        'xgboost', # XGBoost
        'catboost', # CatBoost
        'knn',     # K-Nearest Neighbors
        'mlp',     # Multi-Layer Perceptron
        'svm',     # Support Vector Machine
        'dt',      # Decision Tree
        'ada',     # AdaBoost
        'br'       # Bayesian Ridge
    ],
    sort='RMSE',  # Sort by RMSE (lower is better)
    verbose=False
)

print("✅ Model comparison completed!")
print("\n📊 ALL MODELS COMPARISON RESULTS:")
print("="*80)

# Get the comparison results DataFrame
comparison_results = pull()
display(comparison_results.round(4))

# The best model is already returned by compare_models()
print(f"\n🏆 Best model type: {type(model_comparison).__name__}")
# Out:
# 🤖 Training and comparing multiple regression models...
# This may take a few minutes...
# ✅ Model comparison completed!
#
# 📊 ALL MODELS COMPARISON RESULTS:
# ================================================================================
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/IPython/core/formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/core/frame.py:1136, in _repr_html_(self)
#    1134 # more generally, whatever we allow in NDArrayBackedExtensionBlock
#    1135 arr = cast("np.ndarray | DatetimeArray | TimedeltaArray | PeriodArray", arr)
# -> 1136 return arr.T
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/format.py:1108, in to_html(self, buf, encoding, classes, notebook, border, table_id, render_links)
#    1079 def format_array(
#    1080     values: ArrayLike,
#    1081     formatter: Callable | None,
#    (...)
#    1090     fallback_formatter: Callable | None = None,
#    1091 ) -> list[str]:
#    1092     """
#    1093     Format an array for printing.
#    1094
#    1095     Parameters
#    1096     ----------
#    1097     values : np.ndarray or ExtensionArray
#    1098     formatter
#    1099     float_format
#    1100     na_rep
#    1101     digits
#    1102     space
#    1103     justify
#    1104     decimal
#    1105     leading_space : bool, optional, default True
#    1106         Whether the array should be formatted with a leading space.
#    1107         When an array as a column of a Series or DataFrame, we do want
# -> 1108         the leading space to pad between columns.
#    1109
#    1110         When formatting an Index subclass
#    1111         (e.g. IntervalIndex._get_values_for_csv), we don't want the
#    1112         leading space since it should be left-aligned.
#    1113     fallback_formatter
#    1114
#    1115     Returns
#    1116     -------
#    1117     List[str]
#    1118     """
#    1119     fmt_klass: type[_GenericArrayFormatter]
#    1120     if lib.is_np_dtype(values.dtype, "M"):
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:88, in HTMLFormatter.to_string(self)
#      87 def to_string(self) -> str:
# ---> 88     lines = self.render()
#      89     if any(isinstance(x, str) for x in lines):
#      90         lines = [str(x) for x in lines]
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:644, in NotebookFormatter.render(self)
#     642 self.write("<div>")
#     643 self.write_style()
# --> 644 super().render()
#     645 self.write("</div>")
#     646 return self.elements
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:94, in HTMLFormatter.render(self)
#      93 def render(self) -> list[str]:
# ---> 94     self._write_table()
#      96     if self.should_show_dimensions:
#      97         by = chr(215)  # ×  # noqa: RUF003
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:267, in HTMLFormatter._write_table(self, indent)
#     261 self.write(
#     262     f'<table{border_attr} class="{" ".join(_classes)}"{id_section}>',
#     263     indent,
#     264 )
#     266 if self.fmt.header or self.show_row_idx_names:
# --> 267     self._write_header(indent + self.indent_delta)
#     269 self._write_body(indent + self.indent_delta)
#     271 self.write("</table>", indent)
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:403, in HTMLFormatter._write_header(self, indent)
#     400 self.write("<thead>", indent)
#     402 if self.fmt.header:
# --> 403     self._write_col_header(indent + self.indent_delta)
#     405 if self.show_row_idx_names:
#     406     self._write_row_header(indent + self.indent_delta)
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:383, in HTMLFormatter._write_col_header(self, indent)
#     381     else:
#     382         row.append("")
# --> 383 row.extend(self._get_columns_formatted_values())
#     384 align = self.fmt.justify
#     386 if is_truncated_horizontally:
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:611, in NotebookFormatter._get_columns_formatted_values(self)
#     609 def _get_columns_formatted_values(self) -> list[str]:
#     610     # only reached with non-Multi Index
# --> 611     return self.columns._format_flat(include_name=False)
#
# AttributeError: 'Index' object has no attribute '_format_flat'
#                                     Model        MAE           MSE       RMSE  \
# catboost               CatBoost Regressor   241.2144  1.026951e+05   318.1994
# ada                    AdaBoost Regressor   250.5960  1.098178e+05   330.1690
# rf                Random Forest Regressor   251.3261  1.135517e+05   334.6180
# gbr           Gradient Boosting Regressor   256.6278  1.143671e+05   335.9524
# et                  Extra Trees Regressor   256.2150  1.197696e+05   344.2187
# xgboost         Extreme Gradient Boosting   271.5624  1.378923e+05   367.5547
# dt                Decision Tree Regressor   283.0405  1.521431e+05   386.5226
# lightgbm  Light Gradient Boosting Machine   301.9886  1.878845e+05   422.9651
# lr                      Linear Regression   354.5392  2.693535e+05   508.4264
# knn                 K Neighbors Regressor   364.7195  3.162262e+05   555.0810
# huber                     Huber Regressor   367.7854  3.997024e+05   607.2249
# en                            Elastic Net   401.9685  4.046939e+05   614.2888
# ridge                    Ridge Regression   413.9827  4.045785e+05   617.9522
# br                         Bayesian Ridge   414.0104  4.083009e+05   620.0977
# lasso                    Lasso Regression   415.6347  4.076090e+05   620.2852
# svm             Support Vector Regression   376.0112  4.297814e+05   630.6052
# mlp                         MLP Regressor  7076.9098  5.050432e+07  7106.1933
#
#                 R2   RMSLE    MAPE  TT (Sec)
# catboost    0.6534  0.0441  0.0324     1.172
# ada         0.6352  0.0465  0.0339     0.022
# rf          0.6115  0.0473  0.0340     0.106
# gbr         0.6056  0.0467  0.0346     0.052
# et          0.5959  0.0478  0.0345     0.040
# xgboost     0.5679  0.0533  0.0374     0.074
# dt          0.4979  0.0532  0.0378     0.008
# lightgbm    0.4133  0.0634  0.0422     0.090
# lr          0.0279  0.0756  0.0484     0.018
# knn         0.1024  0.0827  0.0520     0.016
# huber       0.0279  0.0906  0.0548     0.014
# en         -0.0026  0.0907  0.0584     0.008
# ridge      -0.0303  0.0908  0.0596     0.010
# br         -0.0346  0.0911  0.0597     0.008
# lasso      -0.0382  0.0911  0.0599     0.010
# svm        -0.0500  0.0936  0.0563     0.008
# mlp      -163.7657  2.4260  0.9109     0.046
# 🏆 Best model type: CatBoostRegressor

# %%
# ========================================
# OVERFITTING ANALYSIS FOR PYCARET MODELS
# ========================================

print("\n" + "="*80)
print("🔍 COMPREHENSIVE OVERFITTING ANALYSIS")
print("="*80)

# Get the comparison results (cross-validation scores)
model_comparison = pull()
print("📊 Cross-validation results:")
display(model_comparison.round(4))

# Get top 5 models for detailed analysis
top_models = model_comparison.head(5).index.tolist()
print(f"\n🎯 Analyzing top {len(top_models)} models for overfitting...")

# Store detailed results
detailed_results = []

for i, model_name in enumerate(top_models, 1):
    print(f"\n{'='*60}")
    print(f"📊 MODEL {i}: {model_name.upper()}")
    print(f"{'='*60}")
    
    # Create the model
    model = create_model(model_name, verbose=False)
    
    # Get training and test data from PyCaret setup
    X_train = get_config('X_train')
    y_train = get_config('y_train')
    X_test = get_config('X_test') 
    y_test = get_config('y_test')
    
    # Make predictions on both sets
    train_pred = model.predict(X_train)
    test_pred = model.predict(X_test)
    
    # Calculate metrics
    from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
    import numpy as np
    
    # Training metrics
    train_rmse = np.sqrt(mean_squared_error(y_train, train_pred))
    train_r2 = r2_score(y_train, train_pred)
    
    # Test metrics
    test_rmse = np.sqrt(mean_squared_error(y_test, test_pred))
    test_r2 = r2_score(y_test, test_pred)
    
    # CV metrics (from comparison)
    cv_rmse = model_comparison.loc[model_name, 'RMSE']
    cv_r2 = model_comparison.loc[model_name, 'R2']
    
    # Create comparison
    performance_df = pd.DataFrame({
        'Dataset': ['Cross-Validation', 'Training Set', 'Test Set'],
        'RMSE': [cv_rmse, train_rmse, test_rmse],
        'R²': [cv_r2, train_r2, test_r2]
    })
    
    print("📊 Performance Comparison:")
    display(performance_df.round(6))
    
    # Overfitting assessment
    r2_drop = train_r2 - test_r2
    rmse_increase_pct = ((test_rmse - train_rmse) / train_rmse) * 100
    
    print(f"\n🔍 Overfitting Indicators:")
    print(f"   R² drop (train→test): {r2_drop:.4f}")
    print(f"   RMSE increase: {rmse_increase_pct:.2f}%")
    
    # Assessment
    if r2_drop > 0.15 or rmse_increase_pct > 25:
        assessment = "🔴 HIGH OVERFITTING"
    elif r2_drop > 0.1 or rmse_increase_pct > 15:
        assessment = "🟡 MODERATE OVERFITTING"
    else:
        assessment = "🟢 GOOD GENERALIZATION"
    
    print(f"   Overall: {assessment}")
    
    # Store results
    detailed_results.append({
        'Model': model_name,
        'CV_RMSE': cv_rmse,
        'Train_RMSE': train_rmse,
        'Test_RMSE': test_rmse,
        'CV_R2': cv_r2,
        'Train_R2': train_r2,
        'Test_R2': test_r2,
        'R2_Drop': r2_drop,
        'RMSE_Increase_%': rmse_increase_pct,
        'Assessment': assessment.split()[-1]
    })

# Summary table
print(f"\n{'='*80}")
print("📋 OVERFITTING SUMMARY")
print(f"{'='*80}")

summary_df = pd.DataFrame(detailed_results)
display(summary_df.round(4))

# Recommendations
best_model = summary_df[summary_df['Assessment'] == 'GENERALIZATION']
if len(best_model) > 0:
    recommended = best_model.loc[best_model['Test_RMSE'].idxmin(), 'Model']
    print(f"\n🏆 RECOMMENDED MODEL: {recommended}")
    print("   ✅ Shows good generalization with lowest test error")
else:
    print(f"\n⚠️  All models show some overfitting. Choose the least problematic one.")
# Out:
# ================================================================================
# 🔍 COMPREHENSIVE OVERFITTING ANALYSIS
# ================================================================================
# 📊 Cross-validation results:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/IPython/core/formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/core/frame.py:1136, in _repr_html_(self)
#    1134 # more generally, whatever we allow in NDArrayBackedExtensionBlock
#    1135 arr = cast("np.ndarray | DatetimeArray | TimedeltaArray | PeriodArray", arr)
# -> 1136 return arr.T
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/format.py:1108, in to_html(self, buf, encoding, classes, notebook, border, table_id, render_links)
#    1079 def format_array(
#    1080     values: ArrayLike,
#    1081     formatter: Callable | None,
#    (...)
#    1090     fallback_formatter: Callable | None = None,
#    1091 ) -> list[str]:
#    1092     """
#    1093     Format an array for printing.
#    1094
#    1095     Parameters
#    1096     ----------
#    1097     values : np.ndarray or ExtensionArray
#    1098     formatter
#    1099     float_format
#    1100     na_rep
#    1101     digits
#    1102     space
#    1103     justify
#    1104     decimal
#    1105     leading_space : bool, optional, default True
#    1106         Whether the array should be formatted with a leading space.
#    1107         When an array as a column of a Series or DataFrame, we do want
# -> 1108         the leading space to pad between columns.
#    1109
#    1110         When formatting an Index subclass
#    1111         (e.g. IntervalIndex._get_values_for_csv), we don't want the
#    1112         leading space since it should be left-aligned.
#    1113     fallback_formatter
#    1114
#    1115     Returns
#    1116     -------
#    1117     List[str]
#    1118     """
#    1119     fmt_klass: type[_GenericArrayFormatter]
#    1120     if lib.is_np_dtype(values.dtype, "M"):
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:88, in HTMLFormatter.to_string(self)
#      87 def to_string(self) -> str:
# ---> 88     lines = self.render()
#      89     if any(isinstance(x, str) for x in lines):
#      90         lines = [str(x) for x in lines]
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:644, in NotebookFormatter.render(self)
#     642 self.write("<div>")
#     643 self.write_style()
# --> 644 super().render()
#     645 self.write("</div>")
#     646 return self.elements
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:94, in HTMLFormatter.render(self)
#      93 def render(self) -> list[str]:
# ---> 94     self._write_table()
#      96     if self.should_show_dimensions:
#      97         by = chr(215)  # ×  # noqa: RUF003
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:267, in HTMLFormatter._write_table(self, indent)
#     261 self.write(
#     262     f'<table{border_attr} class="{" ".join(_classes)}"{id_section}>',
#     263     indent,
#     264 )
#     266 if self.fmt.header or self.show_row_idx_names:
# --> 267     self._write_header(indent + self.indent_delta)
#     269 self._write_body(indent + self.indent_delta)
#     271 self.write("</table>", indent)
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:403, in HTMLFormatter._write_header(self, indent)
#     400 self.write("<thead>", indent)
#     402 if self.fmt.header:
# --> 403     self._write_col_header(indent + self.indent_delta)
#     405 if self.show_row_idx_names:
#     406     self._write_row_header(indent + self.indent_delta)
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:383, in HTMLFormatter._write_col_header(self, indent)
#     381     else:
#     382         row.append("")
# --> 383 row.extend(self._get_columns_formatted_values())
#     384 align = self.fmt.justify
#     386 if is_truncated_horizontally:
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:611, in NotebookFormatter._get_columns_formatted_values(self)
#     609 def _get_columns_formatted_values(self) -> list[str]:
#     610     # only reached with non-Multi Index
# --> 611     return self.columns._format_flat(include_name=False)
#
# AttributeError: 'Index' object has no attribute '_format_flat'
#                                     Model        MAE           MSE       RMSE  \
# catboost               CatBoost Regressor   241.2144  1.026951e+05   318.1994
# ada                    AdaBoost Regressor   250.5960  1.098178e+05   330.1690
# rf                Random Forest Regressor   251.3261  1.135517e+05   334.6180
# gbr           Gradient Boosting Regressor   256.6278  1.143671e+05   335.9524
# et                  Extra Trees Regressor   256.2150  1.197696e+05   344.2187
# xgboost         Extreme Gradient Boosting   271.5624  1.378923e+05   367.5547
# dt                Decision Tree Regressor   283.0405  1.521431e+05   386.5226
# lightgbm  Light Gradient Boosting Machine   301.9886  1.878845e+05   422.9651
# lr                      Linear Regression   354.5392  2.693535e+05   508.4264
# knn                 K Neighbors Regressor   364.7195  3.162262e+05   555.0810
# huber                     Huber Regressor   367.7854  3.997024e+05   607.2249
# en                            Elastic Net   401.9685  4.046939e+05   614.2888
# ridge                    Ridge Regression   413.9827  4.045785e+05   617.9522
# br                         Bayesian Ridge   414.0104  4.083009e+05   620.0977
# lasso                    Lasso Regression   415.6347  4.076090e+05   620.2852
# svm             Support Vector Regression   376.0112  4.297814e+05   630.6052
# mlp                         MLP Regressor  7076.9098  5.050432e+07  7106.1933
#
#                 R2   RMSLE    MAPE  TT (Sec)
# catboost    0.6534  0.0441  0.0324     1.172
# ada         0.6352  0.0465  0.0339     0.022
# rf          0.6115  0.0473  0.0340     0.106
# gbr         0.6056  0.0467  0.0346     0.052
# et          0.5959  0.0478  0.0345     0.040
# xgboost     0.5679  0.0533  0.0374     0.074
# dt          0.4979  0.0532  0.0378     0.008
# lightgbm    0.4133  0.0634  0.0422     0.090
# lr          0.0279  0.0756  0.0484     0.018
# knn         0.1024  0.0827  0.0520     0.016
# huber       0.0279  0.0906  0.0548     0.014
# en         -0.0026  0.0907  0.0584     0.008
# ridge      -0.0303  0.0908  0.0596     0.010
# br         -0.0346  0.0911  0.0597     0.008
# lasso      -0.0382  0.0911  0.0599     0.010
# svm        -0.0500  0.0936  0.0563     0.008
# mlp      -163.7657  2.4260  0.9109     0.046
# 🎯 Analyzing top 5 models for overfitting...
#
# ============================================================
# 📊 MODEL 1: CATBOOST
# ============================================================
# 📊 Performance Comparison:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/IPython/core/formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/core/frame.py:1136, in _repr_html_(self)
#    1134 # more generally, whatever we allow in NDArrayBackedExtensionBlock
#    1135 arr = cast("np.ndarray | DatetimeArray | TimedeltaArray | PeriodArray", arr)
# -> 1136 return arr.T
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/format.py:1108, in to_html(self, buf, encoding, classes, notebook, border, table_id, render_links)
#    1079 def format_array(
#    1080     values: ArrayLike,
#    1081     formatter: Callable | None,
#    (...)
#    1090     fallback_formatter: Callable | None = None,
#    1091 ) -> list[str]:
#    1092     """
#    1093     Format an array for printing.
#    1094
#    1095     Parameters
#    1096     ----------
#    1097     values : np.ndarray or ExtensionArray
#    1098     formatter
#    1099     float_format
#    1100     na_rep
#    1101     digits
#    1102     space
#    1103     justify
#    1104     decimal
#    1105     leading_space : bool, optional, default True
#    1106         Whether the array should be formatted with a leading space.
#    1107         When an array as a column of a Series or DataFrame, we do want
# -> 1108         the leading space to pad between columns.
#    1109
#    1110         When formatting an Index subclass
#    1111         (e.g. IntervalIndex._get_values_for_csv), we don't want the
#    1112         leading space since it should be left-aligned.
#    1113     fallback_formatter
#    1114
#    1115     Returns
#    1116     -------
#    1117     List[str]
#    1118     """
#    1119     fmt_klass: type[_GenericArrayFormatter]
#    1120     if lib.is_np_dtype(values.dtype, "M"):
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:88, in HTMLFormatter.to_string(self)
#      87 def to_string(self) -> str:
# ---> 88     lines = self.render()
#      89     if any(isinstance(x, str) for x in lines):
#      90         lines = [str(x) for x in lines]
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:644, in NotebookFormatter.render(self)
#     642 self.write("<div>")
#     643 self.write_style()
# --> 644 super().render()
#     645 self.write("</div>")
#     646 return self.elements
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:94, in HTMLFormatter.render(self)
#      93 def render(self) -> list[str]:
# ---> 94     self._write_table()
#      96     if self.should_show_dimensions:
#      97         by = chr(215)  # ×  # noqa: RUF003
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:267, in HTMLFormatter._write_table(self, indent)
#     261 self.write(
#     262     f'<table{border_attr} class="{" ".join(_classes)}"{id_section}>',
#     263     indent,
#     264 )
#     266 if self.fmt.header or self.show_row_idx_names:
# --> 267     self._write_header(indent + self.indent_delta)
#     269 self._write_body(indent + self.indent_delta)
#     271 self.write("</table>", indent)
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:403, in HTMLFormatter._write_header(self, indent)
#     400 self.write("<thead>", indent)
#     402 if self.fmt.header:
# --> 403     self._write_col_header(indent + self.indent_delta)
#     405 if self.show_row_idx_names:
#     406     self._write_row_header(indent + self.indent_delta)
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:383, in HTMLFormatter._write_col_header(self, indent)
#     381     else:
#     382         row.append("")
# --> 383 row.extend(self._get_columns_formatted_values())
#     384 align = self.fmt.justify
#     386 if is_truncated_horizontally:
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/pandas/io/formats/html.py:611, in NotebookFormatter._get_columns_formatted_values(self)
#     609 def _get_columns_formatted_values(self) -> list[str]:
#     610     # only reached with non-Multi Index
# --> 611     return self.columns._format_flat(include_name=False)
#
# AttributeError: 'Index' object has no attribute '_format_flat'
#             Dataset        RMSE        R²
# 0  Cross-Validation  318.199400  0.653400
# 1      Training Set  278.583539  0.812148
# 2          Test Set  447.435174  0.319013
# 🔍 Overfitting Indicators:
#    R² drop (train→test): 0.4931
#    RMSE increase: 60.61%
#    Overall: 🔴 HIGH OVERFITTING
#
# ============================================================
# 📊 MODEL 2: ADA
# ============================================================
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 36
#      33 y_test = get_config('y_test')
#      35 # Make predictions on both sets
# ---> 36 train_pred = model.predict(X_train)
#      37 test_pred = model.predict(X_test)
#      39 # Calculate metrics
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/sklearn/ensemble/_weight_boosting.py:1238, in AdaBoostRegressor.predict(self, X)
#    1221 """Predict regression value for X.
#    1222
#    1223 The predicted regression value of an input sample is computed
#    (...)
#    1235     The predicted regression values.
#    1236 """
#    1237 check_is_fitted(self)
# -> 1238 X = self._check_X(X)
#    1240 return self._get_median_predict(X, len(self.estimators_))
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/sklearn/ensemble/_weight_boosting.py:98, in BaseWeightBoosting._check_X(self, X)
#      96 def _check_X(self, X):
#      97     # Only called to validate X in non-fit methods, therefore reset=False
# ---> 98     return self._validate_data(
#      99         X,
#     100         accept_sparse=["csr", "csc"],
#     101         ensure_2d=True,
#     102         allow_nd=True,
#     103         dtype=None,
#     104         reset=False,
#     105     )
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/sklearn/base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py:1049, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1043     raise ValueError(
#    1044         "Found array with dim %d. %s expected <= 2."
#    1045         % (array.ndim, estimator_name)
#    1046     )
#    1048 if force_all_finite:
# -> 1049     _assert_all_finite(
#    1050         array,
#    1051         input_name=input_name,
#    1052         estimator_name=estimator_name,
#    1053         allow_nan=force_all_finite == "allow-nan",
#    1054     )
#    1056 if copy:
#    1057     if _is_numpy_namespace(xp):
#    1058         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py:126, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     123 if first_pass_isfinite:
#     124     return
# --> 126 _assert_all_finite_element_wise(
#     127     X,
#     128     xp=xp,
#     129     allow_nan=allow_nan,
#     130     msg_dtype=msg_dtype,
#     131     estimator_name=estimator_name,
#     132     input_name=input_name,
#     133 )
#
# File ~/Desktop/Battery-Capacity/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py:175, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     158 if estimator_name and input_name == "X" and has_nan_error:
#     159     # Improve the error message on how to handle missing values in
#     160     # scikit-learn.
#     161     msg_err += (
#     162         f"\n{estimator_name} does not accept missing values"
#     163         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     173         "#estimators-that-handle-nan-values"
#     174     )
# --> 175 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# AdaBoostRegressor does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
# Save comparison results and display top performers
comparison_file = results_dir / "pycaret_model_comparison.csv"
model_comparison.to_csv(comparison_file)
print(f"💾 Results saved to: {comparison_file}")

# Display top 5 models
print("\n🏆 TOP 5 BEST PERFORMING MODELS:")
print("="*50)
top_5 = model_comparison.head(5)
for i, (idx, row) in enumerate(top_5.iterrows(), 1):
    print(f"{i}. {idx}: RMSE={row['RMSE']:.6f}, R²={row['R2']:.6f}, MAE={row['MAE']:.6f}")

# %%
# Get the best model and create it
best_model_name = model_comparison.index[0]
print(f"🏆 Best performing model: {best_model_name}")
print(f"📊 Best RMSE: {model_comparison.iloc[0]['RMSE']:.6f}")
print(f"📈 Best R²: {model_comparison.iloc[0]['R2']:.6f}")

# Create the best model
print("\n🔧 Creating and training the best model...")
best_model = create_model(best_model_name, verbose=False)

print(f"✅ Best model created: {type(best_model).__name__}")

# %%
# Tune hyperparameters of the best model
print("🔧 Tuning hyperparameters of the best model...")
tuned_model = tune_model(best_model, verbose=False)
print("✅ Hyperparameter tuning completed!")

# %%
# Evaluate the tuned model with plots
print("📊 Evaluating the tuned model...")
evaluate_model(tuned_model)

# %%
# Finalize the model and make predictions
print("🎯 Finalizing model on full dataset...")
final_model = finalize_model(tuned_model)

# Make predictions on test set
print("🔮 Making predictions on test set...")
predictions = predict_model(final_model)

print("\n📈 PREDICTION RESULTS (First 10 samples):")
print("="*50)
display(predictions[['target', 'prediction_label', 'prediction_residuals']].head(10).round(4))

# %%
# Calculate final performance metrics
from sklearn.metrics import mean_absolute_error, r2_score

y_true = predictions['target']
y_pred = predictions['prediction_label']

mae = mean_absolute_error(y_true, y_pred)
r2 = r2_score(y_true, y_pred)
rmse = np.sqrt(np.mean((y_true - y_pred) ** 2))

print("\n📊 FINAL MODEL PERFORMANCE ON TEST SET:")
print("="*50)
print(f"🎯 Mean Absolute Error (MAE): {mae:.6f}")
print(f"📏 Root Mean Square Error (RMSE): {rmse:.6f}")
print(f"📈 R² Score: {r2:.6f}")
print(f"📊 Model Type: {type(final_model).__name__}")

# Performance interpretation
print("\n🔍 PERFORMANCE INTERPRETATION:")
print("="*40)
if r2 > 0.9:
    print("🌟 Excellent performance! The model explains >90% of variance.")
elif r2 > 0.8:
    print("✅ Very good performance! The model explains >80% of variance.")
elif r2 > 0.7:
    print("👍 Good performance! The model explains >70% of variance.")
else:
    print("⚠️  Moderate performance. Consider feature engineering or more data.")

avg_capacity = y_true.mean()
mae_percentage = (mae / avg_capacity) * 100
print(f"📊 Average prediction error: {mae_percentage:.2f}% of average capacity")

# %%
# Save the final model and predictions
model_file = results_dir / "pycaret_best_model"
save_model(final_model, str(model_file))
print(f"💾 Best model saved to: {model_file}.pkl")

predictions_file = results_dir / "pycaret_predictions.csv"
predictions.to_csv(predictions_file, index=False)
print(f"💾 Predictions saved to: {predictions_file}")

# %%
# Generate visualization plots
print("📊 Generating visualization plots...")

try:
    # Residuals plot
    plot_model(final_model, plot='residuals', display_format='streamlit')
    
    # Prediction error plot  
    plot_model(final_model, plot='error', display_format='streamlit')
    
    # Feature importance (if available)
    if hasattr(final_model, 'feature_importances_') or hasattr(final_model, 'coef_'):
        plot_model(final_model, plot='feature', display_format='streamlit')
        
    print("✅ All plots generated successfully!")
    
except Exception as e:
    print(f"⚠️  Some plots could not be generated: {e}")

# %%
# Final Summary
print("\n" + "="*80)
print("🎉 PYCARET ANALYSIS SUMMARY")
print("="*80)
print(f"📊 Total models tested: {len(model_comparison)}")
print(f"🏆 Best model: {type(final_model).__name__}")
print(f"🎯 Final RMSE: {rmse:.6f}")
print(f"📈 Final R² Score: {r2:.6f}")
print(f"🎯 Final MAE: {mae:.6f}")
print(f"📊 Average prediction error: {mae_percentage:.2f}%")
print(f"📁 All results saved in: {results_dir}")

print("\n🔝 TOP 3 MODELS:")
for i in range(min(3, len(model_comparison))):
    model_name = model_comparison.index[i]
    rmse_val = model_comparison.iloc[i]['RMSE']
    r2_val = model_comparison.iloc[i]['R2']
    print(f"  {i+1}. {model_name}: RMSE={rmse_val:.6f}, R²={r2_val:.6f}")

print("="*80)
